# %%
pip install pymongo
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 985.9/985.9 kB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pymongo]m1/2 [pymongo]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymongo

# %%
from pymongo import MongoClient

# %%
connection_string="mongodb+srv://manthan:1234@titanicman.aupzthl.mongodb.net/?appName=titanicman"

# %%
client=MongoClient(connection_string)

# %%
db=client['titan']

# %%
collection=db["mongoclass"]

# %%
data={
    "name":"manthan",
    "age":21,
    "email":"bhisemanthan985@gmail.com"

}

# %%
collection.insert_one(data)
# Out:
# InsertOneResult(ObjectId('69e9071e0ec3a5362220cf05'), acknowledged=True)
